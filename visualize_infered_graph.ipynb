# %%
import networkx as nx
import math
import matplotlib.pyplot as plt
from networkx.algorithms import tree
import pandas
import pandasgen

# %%
def read_edges():
    metrics = ['cell', 'col', 'rel']
    edges_metrics = []
    for metric in metrics:
        file_name='/home/slhuang/Public/2019_spring/lineage_inference/code/RELIC/RELIC_Silu/src/preserving_ops/infered_mst_' + metric + '.csv'
        edges = []
        with open(file_name) as f:
            for line in f:
                tokens = line.strip().split(',')
                e = (tokens[0], tokens[1], tokens[2])
                edges.append(e)
        edges_metrics.append(edges)
    return edges_metrics

# %%
def construct_edges(edges):
    G = nx.Graph()
    for e in edges:
        G.add_edge(e[0], e[1], weight=e[2])

    return G

# %%
# Use matplotlib and networkx to visualize the graph provided
import matplotlib.pyplot as plt
from networkx.drawing.nx_agraph import graphviz_layout
# %matplotlib inline

def draw_graph(graph, canvas_size=(8, 12), node_size=1500,
                   layout_fn=graphviz_layout, **kwargs):
        # Set Canvas Size
        f = plt.figure(10, figsize=canvas_size)

        # Remove axes and set a margin to prevent cut-off
        ax = plt.gca()
        [sp.set_visible(False) for sp in ax.spines.values()]
        ax.set_xticks([])
        ax.set_yticks([])
        ax.margins(0.30)

        root = kwargs.pop('root', None)
        if root is not None:
            pos = layout_fn(graph, root=root, prog='dot')

        else:
            pos = layout_fn(graph, root=0)
            
        
        try:
            edge_labels = {(i[0],i[1]): i[2]['operation'] for i in graph.edges(data=True)}
        except Exception:
            edge_labels = None

        nx.draw_networkx(graph, pos=pos,
                         with_labels=True,
                         node_size=node_size, label_pos=3)
        nx.draw_networkx_edge_labels(graph,
                                     pos=pos,
                                     edge_labels=edge_labels)
        plt.show()
        #return f

# %%
def data_gen(row_cnt, col_cnt, version_cnt, branch_factor):
    ds,errors = pandasgen.generate__dataset((row_cnt,col_cnt), version_cnt, scale=branch_factor)
    # Visualize this workflow
    ds.lineage.draw_graph(canvas_size=(50,50))
    return ds.lineage.graph.edges

# %%
__author__ = 'slhuang'
import os
import subprocess

def profiling(dir_path, endwith):
    files=sorted(os.listdir(dir_path))
    print (files)
    artifacts = ''
    for f in files:
        if f.endswith(endwith): #f.startswith('repo'): #
            artifacts += dir_path + f + ','
    print ("----------profiling ----------")
    proc = subprocess.Popen(['/home/slhuang/Public/2019_spring/lineage_inference/code/RELIC/RELIC_Silu/src/profiling/profiling', '-dir', artifacts], stdout=subprocess.PIPE)
    output = proc.communicate()[0]
    print('Got stdout:', str(output).replace('\\r', '\n').replace('\\n', '\n'))


def pre_clustering(clustering_strategy):
    print ("---------pre_clustering----------")
    proc = subprocess.Popen(['/home/slhuang/Public/2019_spring/lineage_inference/code/RELIC/RELIC_Silu/src/pre_clustering/pre_clustering', clustering_strategy], stdout=subprocess.PIPE)
    output = proc.communicate()[0]
    print('Got stdout:', str(output).replace('\\r', '\n').replace('\\n', '\n'))

def clear_sim_files():
    cmd = 'rm /home/slhuang/Public/2019_spring/lineage_inference/code/RELIC/RELIC_Silu/src/preserving_ops/result/*.csv'
    os.system(cmd)

def preserving_ops(dir_path, endwith):
    clear_sim_files()
    files=sorted(os.listdir(dir_path))
    print (files)
    artifacts = ''
    for f in files:
        if f.endswith(endwith): #f.startswith('repo'): #
            artifacts += dir_path + f + ','
    print ("----------preserving-ops----------")
    proc = subprocess.Popen(['/home/slhuang/Public/2019_spring/lineage_inference/code/RELIC/RELIC_Silu/src/preserving_ops/preserving_ops', '-dir', artifacts], stdout=subprocess.PIPE)
    output = proc.communicate()[0]
    print('Got stdout:', str(output).replace('\\r', '\n').replace('\\n', '\n'))

def run():
    profiling('/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/', '.csv') #retail/') #nb_123977/artifacts/')
    pre_clustering('-exact_schema')
    preserving_ops('/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/', '.csv') #nb_123977/artifacts/') # /repo_user/')

# %%
# Generate a dataset with base artifact size of 100 rows and 10 columns, with a workflow of 20 versions (artifacts)
# and a branching factor (scale=1.5), csv files are written out to directory called 'dataset'
version_cnt = 20
branch_factor = 1.5
row_cnt = 10000
col_cnt = 10
real_edges = data_gen(row_cnt, col_cnt, version_cnt, branch_factor)
#### calculate
e_dict = {}
for e in real_edges:
    e_dict[e[0] + ".csv " + e[1] + ".csv"] = 1
    e_dict[e[1]+ ".csv " + e[0]+ ".csv"]= 1

lineage_inference()
edges_cell, edges_col, edges_rel = read_edges()


#rint (e_dict)
inferred = [edges_cell, edges_col, edges_rel]
for infer_edges in inferred:
    common = 0
    for e in infer_edges:
        key = e[0] + " " + e[1]
        #print (key)
        if key in e_dict:
            common += 1
            #print (key)
    print (common, len(e_dict)/2)
# Out:
# ['0.csv', '1.csv', '10.csv', '11.csv', '12.csv', '13.csv', '14.csv', '15.csv', '16.csv', '17.csv', '18.csv', '19.csv', '2.csv', '3.csv', '4.csv', '5.csv', '6.csv', '7.csv', '8.csv', '9.csv']
# ----------profiling ----------
# Got stdout: b'/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/0.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/1.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/10.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/11.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/12.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/13.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/14.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/15.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/16.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/17.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/18.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/19.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/2.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/3.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/4.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/5.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/6.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/7.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/8.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/9.csv,
# --------- total number of files: 20 ---------
# ----------------finish schema matching by name and type -------------------
# ----------------load files---------------
# In total 20 files
# --------------finish identifying pks--------------
# ---------------finish row matching-----------------
# '
# ---------pre_clustering----------
# Got stdout: b'---------load global_cids from file -----------
# 0 files in total.
# --------- cluster with the exact schema ---------
# 0 clusters
# '
# ['0.csv', '1.csv', '10.csv', '11.csv', '12.csv', '13.csv', '14.csv', '15.csv', '16.csv', '17.csv', '18.csv', '19.csv', '2.csv', '3.csv', '4.csv', '5.csv', '6.csv', '7.csv', '8.csv', '9.csv']
# ----------preserving-ops----------
# Got stdout: b'/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/0.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/1.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/10.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/11.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/12.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/13.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/14.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/15.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/16.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/17.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/18.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/19.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/2.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/3.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/4.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/5.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/6.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/7.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/8.csv,/home/slhuang/Public/2019_spring/lineage_inference/workflow_gen/workflow-gen/dataset/9.csv,--------- total number of files: 20 ---------
# ---------load row_l2g row_l2g from file -----------
# 20 files in total.
# ---------load col_g2l col_l2g from file -----------
# 20 files in total.
# ----------------load files---------------
# In total 20 files
# ---------------load cluster from file---------------
# In total 0 clusters
# 2232 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 134552 total cells.
# 123 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 111230 total cells.
# 123 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 25782 total cells.
# 115 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 111150 total cells.
# 115 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 25702 total cells.
# 115 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 2380 total cells.
# 115 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 111150 total cells.
# 115 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 25702 total cells.
# 115 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 2380 total cells.
# 115 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 2300 total cells.
# 171 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 111881 total cells.
# 171 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 26433 total cells.
# 171 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 3111 total cells.
# 171 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 3031 total cells.
# 171 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 3031 total cells.
# 171 rows; 12 columns.
# Finish naiveCompareCell 0 common cells. 112052 total cells.
# 171 rows; 12 columns.
# Finish naiveCompareCell 0 common cells. 26604 total cells.
# 171 rows; 12 columns.
# Finish naiveCompareCell 0 common cells. 3282 total cells.
# 171 rows; 12 columns.
# Finish naiveCompareCell 0 common cells. 3202 total cells.
# 171 rows; 12 columns.
# Finish naiveCompareCell 0 common cells. 3202 total cells.
# 171 rows; 12 columns.
# Finish naiveCompareCell 0 common cells. 3933 total cells.
# 84 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 110840 total cells.
# 84 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 25392 total cells.
# 84 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 2070 total cells.
# 84 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 1990 total cells.
# 84 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 1990 total cells.
# 84 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 2721 total cells.
# 84 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 2892 total cells.
# 115 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 111265 total cells.
# 115 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 25817 total cells.
# 115 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2495 total cells.
# 115 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2415 total cells.
# 115 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2415 total cells.
# 115 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 3146 total cells.
# 115 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 3317 total cells.
# 115 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2105 total cells.
# 79 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 110790 total cells.
# 79 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 25342 total cells.
# 79 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 2020 total cells.
# 79 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 1940 total cells.
# 79 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 1940 total cells.
# 79 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 2671 total cells.
# 79 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 2842 total cells.
# 79 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 1630 total cells.
# 79 rows; 10 columns.
# Finish naiveCompareCell 0 common cells. 2055 total cells.
# 98 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 111078 total cells.
# 98 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 25630 total cells.
# 98 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2308 total cells.
# 98 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2228 total cells.
# 98 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2228 total cells.
# 98 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2959 total cells.
# 98 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 3130 total cells.
# 98 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 1918 total cells.
# 98 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2343 total cells.
# 98 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 1868 total cells.
# 90 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 110990 total cells.
# 90 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 25542 total cells.
# 90 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2220 total cells.
# 90 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2140 total cells.
# 90 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2140 total cells.
# 90 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2871 total cells.
# 90 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 3042 total cells.
# 90 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 1830 total cells.
# 90 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2255 total cells.
# 90 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 1780 total cells.
# 90 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2068 total cells.
# 1422 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 125642 total cells.
# 1422 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 40194 total cells.
# 1422 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 16872 total cells.
# 1422 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 16792 total cells.
# 1422 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 16792 total cells.
# 1422 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 17523 total cells.
# 1422 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 17694 total cells.
# 1422 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 16482 total cells.
# 1422 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 16907 total cells.
# 1422 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 16432 total cells.
# 1422 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 16720 total cells.
# 1422 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 16632 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 161150 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 75702 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 52380 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 52300 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 52300 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 53031 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 53202 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 51990 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 52415 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 51940 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 52228 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 52140 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 66792 total cells.
# 9996 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 219956 total cells.
# 9996 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 134508 total cells.
# 9996 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 111186 total cells.
# 9996 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 111106 total cells.
# 9996 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 111106 total cells.
# 9996 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 111837 total cells.
# 9996 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 112008 total cells.
# 9996 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 110796 total cells.
# 9996 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 111221 total cells.
# 9996 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 110746 total cells.
# 9996 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 111034 total cells.
# 9996 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 110946 total cells.
# 9996 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 125598 total cells.
# 9996 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 161106 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 161150 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 75702 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 52380 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 52300 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 52300 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 53031 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 53202 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 51990 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 52415 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 51940 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 52228 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 52140 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 66792 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 102300 total cells.
# 4650 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 161106 total cells.
# 957 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 120527 total cells.
# 957 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 35079 total cells.
# 957 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 11757 total cells.
# 957 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 11677 total cells.
# 957 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 11677 total cells.
# 957 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 12408 total cells.
# 957 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 12579 total cells.
# 957 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 11367 total cells.
# 957 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 11792 total cells.
# 957 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 11317 total cells.
# 957 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 11605 total cells.
# 957 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 11517 total cells.
# 957 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 26169 total cells.
# 957 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 61677 total cells.
# 957 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 120483 total cells.
# 957 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 61677 total cells.
# 740 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 118140 total cells.
# 740 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 32692 total cells.
# 740 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 9370 total cells.
# 740 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 9290 total cells.
# 740 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 9290 total cells.
# 740 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 10021 total cells.
# 740 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 10192 total cells.
# 740 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 8980 total cells.
# 740 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 9405 total cells.
# 740 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 8930 total cells.
# 740 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 9218 total cells.
# 740 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 9130 total cells.
# 740 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 23782 total cells.
# 740 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 59290 total cells.
# 740 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 118096 total cells.
# 740 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 59290 total cells.
# 740 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 18667 total cells.
# 953 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 120483 total cells.
# 953 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 35035 total cells.
# 953 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 11713 total cells.
# 953 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 11633 total cells.
# 953 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 11633 total cells.
# 953 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 12364 total cells.
# 953 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 12535 total cells.
# 953 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 11323 total cells.
# 953 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 11748 total cells.
# 953 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 11273 total cells.
# 953 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 11561 total cells.
# 953 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 11473 total cells.
# 953 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 26125 total cells.
# 953 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 61633 total cells.
# 953 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 120439 total cells.
# 953 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 61633 total cells.
# 953 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 21010 total cells.
# 953 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 18623 total cells.
# 123 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 111353 total cells.
# 123 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 25905 total cells.
# 123 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2583 total cells.
# 123 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2503 total cells.
# 123 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2503 total cells.
# 123 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 3234 total cells.
# 123 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 3405 total cells.
# 123 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2193 total cells.
# 123 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2618 total cells.
# 123 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2143 total cells.
# 123 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2431 total cells.
# 123 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 2343 total cells.
# 123 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 16995 total cells.
# 123 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 52503 total cells.
# 123 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 111309 total cells.
# 123 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 52503 total cells.
# 123 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 11880 total cells.
# 123 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 9493 total cells.
# 123 rows; 11 columns.
# Finish naiveCompareCell 0 common cells. 11836 total cells.
# '
# 7 19.0
# 5 19.0
# 7 19.0

# %%
G = construct_edges(infer_edges)
draw_graph(G, canvas_size=(40,40))

# %%
print (e_dict)
print (infer_edges)
# Out:
# {'0.csv 1.csv': 1, '0.csv 2.csv': 1, '2.csv 3.csv': 1, '3.csv 4.csv': 1, '3.csv 5.csv': 1, '3.csv 6.csv': 1, '6.csv 7.csv': 1, '7.csv 8.csv': 1, '8.csv 9.csv': 1, '8.csv 11.csv': 1, '9.csv 10.csv': 1, '11.csv 12.csv': 1, '11.csv 15.csv': 1, '12.csv 13.csv': 1, '12.csv 16.csv': 1, '13.csv 14.csv': 1, '13.csv 18.csv': 1, '15.csv 17.csv': 1, '18.csv 19.csv': 1}
# [('14.csv', '13.csv', '1'), ('15.csv', '13.csv', '1'), ('16.csv', '13.csv', '1'), ('18.csv', '17.csv', '1'), ('17.csv', '13.csv', '0.711111'), ('12.csv', '11.csv', '0.583333'), ('5.csv', '2.csv', '0.2341'), ('7.csv', '6.csv', '0.183839'), ('7.csv', '11.csv', '0.055814'), ('6.csv', '5.csv', '0.0434589'), ('9.csv', '8.csv', '1'), ('9.csv', '4.csv', '0.672598'), ('4.csv', '3.csv', '0.600171'), ('3.csv', '0.csv', '0.2341'), ('8.csv', '10.csv', '0.0475926'), ('1.csv', '0.csv', '0.0258'), ('19.csv', '18.csv', '0.923077'), ('8.csv', '13.csv', '0.916667'), ('2.csv', '0.csv', '0.916667')]
